# %%
import sys

sys.path.append('/home/kiril/JupyterProjects/intersection-points-between-a-line-and-a-spiral')

from zeta_animation_functions import *

# from Data_classes import *
# import os

# print(os.listdir('/home/kiril/JupyterProjects/intersection-points-between-a-line-and-a-spiral'))

import numpy as np

# %%
def main_func():
    import pygame
    from Data_classes.zeta_data_processing import DataProcessing 

    pygame.init()

    data_processing = DataProcessing()

    screen_width, screen_height, FPS = data_processing.constants.screen_width, \
                                       data_processing.constants.screen_height, \
                                        data_processing.constants.FPS
    font_small = pygame.font.Font(None, data_processing.constants.text_spacing)

    line_color = (185, 185, 185) # Color of the coordinate line

    bg_color = (250, 250, 250)
    
    clock = pygame.time.Clock()


    # Layers
    win = pygame.display.set_mode((screen_width, screen_height)) # Main animation layer

    win.fill(bg_color)

    create_background(*data_processing.background_params, font_small)


    data_processing.blit_layers(win)


    pygame.display.update()
 
    running = True
    
    while running:
        
        clock.tick(FPS) 

        # Check and handle for key control events
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False

            pygame.display.update()

        
    # Exit
    pygame.quit()

main_func()

# %%
import sys

sys.path.append('/home/kiril/JupyterProjects/intersection-points-between-a-line-and-a-spiral')

import animation_functions

# %%
# Out:
# /home/kiril/JupyterProjects/riemman_zeta
